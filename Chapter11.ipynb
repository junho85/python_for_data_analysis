# %%
# https://docs.python.org/2/library/datetime.html
from datetime import datetime

# %%
# datetime

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2015, 11, 19, 18, 17, 39, 372856)

# %%
now.year, now.month, now.day
# Out:
# (2015, 11, 19)

# %%
now.hour, now.minute, now.second,now.microsecond, now.tzinfo
# Out:
# (18, 17, 39, 372856, None)

# %%
delta = datetime(2011,1,7) - datetime(2008,6,24, 8, 15) 
delta
# Out:
# datetime.timedelta(926, 56700)

# %%
delta.days, delta.seconds
# Out:
# (926, 56700)

# %%
# 시간 연산

# %%
from datetime import timedelta

# %%
start = datetime(2011,1,7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
str(start)
# Out:
# '2011-01-07 00:00:00'

# %%
#https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior
start.strftime('%Y-%m-%d')
# Out:
# '2011-01-07'

# %%
value = '20150123'

# %%
dt = datetime.strptime(value, '%Y%m%d')
dt
# Out:
# datetime.datetime(2015, 1, 23, 0, 0)

# %%
# dateutil.parser.parse

# %%
from dateutil.parser import parse

# %%
parse('2011-01-03')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
parse('Jan 31, 1997 10:45 PM')
# Out:
# datetime.datetime(1997, 1, 31, 22, 45)

# %%
parse('31/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 31, 0, 0)

# %%
parse('12/31/2011')
# Out:
# datetime.datetime(2011, 12, 31, 0, 0)

# %%
# 시간 DataFrame

# %%
import pandas as pd
from pandas import DataFrame

# %%
pcmau = pd.read_csv('mail_pcmau.csv', index_col='분 류', thousands=',').T

# %%
pcmau
# Out:
# 분 류  naver.com  daum.net  nate.com  google.com  communication-mail
# 9월-02      1939599  18169858    556665         NaN            20712421
# 10월-02     1927483  17430340    962698         NaN            20044462
# 11월-02     2324534  18684232   1864338         NaN            20998532
# 12월-02     2477848  19103068   3556092         NaN            21393643
# 1월-03      2576350  19090580   5205320         NaN            21419554
# 2월-03      2885544  19338630   5339015         NaN            21347029
# 3월-03      3091230  19854052   5038476         NaN            21992107
# 4월-03      3381671  19252372   4605165         NaN            21800682
# 5월-03      3299419  19254174   4510060         NaN            21889912
# 6월-03      3894331  20410178   4878930         NaN            22951745
# 7월-03      4016301  20746605   4811039         NaN            22972780
# 8월-03      4428060  20186228   5320048         NaN            22379283
# ...

# %%
convert = lambda x: datetime.strptime(x,'%m월-%y')

# %%
pcmau.index
# Out:
# DatetimeIndex(['2002-09-01', '2002-10-01', '2002-11-01', '2002-12-01',
#                '2003-01-01', '2003-02-01', '2003-03-01', '2003-04-01',
#                '2003-05-01', '2003-06-01',
#                ...
#                '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01',
#                '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01',
#                '2015-06-01', '2015-07-01'],
#               dtype='datetime64[ns]', length=155, freq=None, tz=None)

# %%
pcmau.index.map(convert)
# Out:
# array([datetime.datetime(2002, 9, 1, 0, 0),
#        datetime.datetime(2002, 10, 1, 0, 0),
#        datetime.datetime(2002, 11, 1, 0, 0),
#        datetime.datetime(2002, 12, 1, 0, 0),
#        datetime.datetime(2003, 1, 1, 0, 0),
#        datetime.datetime(2003, 2, 1, 0, 0),
#        datetime.datetime(2003, 3, 1, 0, 0),
#        datetime.datetime(2003, 4, 1, 0, 0),
#        datetime.datetime(2003, 5, 1, 0, 0),
#        datetime.datetime(2003, 6, 1, 0, 0),
#        datetime.datetime(2003, 7, 1, 0, 0),
#        datetime.datetime(2003, 8, 1, 0, 0),
#        datetime.datetime(2003, 9, 1, 0, 0),
#        datetime.datetime(2003, 10, 1, 0, 0),
#        datetime.datetime(2003, 11, 1, 0, 0),
#        datetime.datetime(2003, 12, 1, 0, 0),
#        datetime.datetime(2004, 1, 1, 0, 0),
#        datetime.datetime(2004, 2, 1, 0, 0),
#        datetime.datetime(2004, 3, 1, 0, 0),
#        datetime.datetime(2004, 4, 1, 0, 0),
#        datetime.datetime(2004, 5, 1, 0, 0),
# ...

# %%
pcmau.index = pcmau.index.map(convert)

# %%
pcmau
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2002-09-01    1939599  18169858    556665         NaN            20712421
# 2002-10-01    1927483  17430340    962698         NaN            20044462
# 2002-11-01    2324534  18684232   1864338         NaN            20998532
# 2002-12-01    2477848  19103068   3556092         NaN            21393643
# 2003-01-01    2576350  19090580   5205320         NaN            21419554
# 2003-02-01    2885544  19338630   5339015         NaN            21347029
# 2003-03-01    3091230  19854052   5038476         NaN            21992107
# 2003-04-01    3381671  19252372   4605165         NaN            21800682
# 2003-05-01    3299419  19254174   4510060         NaN            21889912
# 2003-06-01    3894331  20410178   4878930         NaN            22951745
# 2003-07-01    4016301  20746605   4811039         NaN            22972780
# 2003-08-01    4428060  20186228   5320048         NaN            22379283
# ...

# %%
# 날짜 범위

# %%
pcmau['2014']
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2014-01-01   17669087  13827592   6298640     1548955            24883209
# 2014-02-01   16806799  13443259   5980735     1382737            24214828
# 2014-03-01   17179211  13890476   6148479     1473548            24699183
# 2014-04-01   16831345  13478635   5994593     1371303            24325197
# 2014-05-01   17442516  13414101   5868764     1518505            24691219
# 2014-06-01   17318585  13201836   5841759     1517366            24568020
# 2014-07-01   17396560  13292901   6035119     1476431            24703403
# 2014-08-01   17057120  13335667   5669171     1484239            24537349
# 2014-09-01   17193074  12959223   5515749     1564786            24380176
# 2014-10-01   17130578  13093149   5740949     1377576            24359396
# 2014-11-01   16857636  12799077   5422418     1473539            24150259
# 2014-12-01   16798943  12749609   5294178     1434281            23913457

# %%
pcmau['2014-01']
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2014-01-01   17669087  13827592   6298640     1548955            24883209

# %%
pcmau.ix['2014-1':'2014-6']
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2014-01-01   17669087  13827592   6298640     1548955            24883209
# 2014-02-01   16806799  13443259   5980735     1382737            24214828
# 2014-03-01   17179211  13890476   6148479     1473548            24699183
# 2014-04-01   16831345  13478635   5994593     1371303            24325197
# 2014-05-01   17442516  13414101   5868764     1518505            24691219
# 2014-06-01   17318585  13201836   5841759     1517366            24568020

# %%
pcmau.ix['2014-1-1':'2014-6']
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2014-01-01   17669087  13827592   6298640     1548955            24883209
# 2014-02-01   16806799  13443259   5980735     1382737            24214828
# 2014-03-01   17179211  13890476   6148479     1473548            24699183
# 2014-04-01   16831345  13478635   5994593     1371303            24325197
# 2014-05-01   17442516  13414101   5868764     1518505            24691219
# 2014-06-01   17318585  13201836   5841759     1517366            24568020

# %%
pd.date_range(start='2014-1-1', periods=365)
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08',
#                '2014-01-09', '2014-01-10',
#                ...
#                '2014-12-22', '2014-12-23', '2014-12-24', '2014-12-25',
#                '2014-12-26', '2014-12-27', '2014-12-28', '2014-12-29',
#                '2014-12-30', '2014-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D', tz=None)

# %%
# 프리퀀시

# %%
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases
# 교재 p.403

# %%
pd.date_range(start='2014-1', periods=12, freq='M')
# Out:
# DatetimeIndex(['2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30',
#                '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31',
#                '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31'],
#               dtype='datetime64[ns]', freq='M', tz=None)

# %%
pd.date_range(start='2014-1', periods=12, freq='MS')
# Out:
# DatetimeIndex(['2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01',
#                '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01',
#                '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01'],
#               dtype='datetime64[ns]', freq='MS', tz=None)

# %%
pd.date_range(start='2014-1', periods=12, freq='BMS')
# Out:
# DatetimeIndex(['2014-02-03', '2014-03-03', '2014-04-01', '2014-05-01',
#                '2014-06-02', '2014-07-01', '2014-08-01', '2014-09-01',
#                '2014-10-01', '2014-11-03', '2014-12-01', '2015-01-01'],
#               dtype='datetime64[ns]', freq='BMS', tz=None)

# %%
# 리샘플링

# %%
pcmau.resample('A')
# Out:
# 분 류           naver.com         daum.net         nate.com      google.com  \
# 2002-12-31   2167366.000000  18346874.500000   1734948.250000             NaN
# 2003-12-31   3841444.416667  20000133.666667   5155450.166667             NaN
# 2004-12-31   7287265.000000  21976173.916667   5826960.250000             NaN
# 2005-12-31  11250731.916667  22434847.000000   5177999.333333   400160.181818
# 2006-12-31  13509387.416667  21852508.583333   4504501.250000   590736.750000
# 2007-12-31  16132152.250000  21134526.666667   4728596.833333   865185.416667
# 2008-12-31  18020378.083333  20839384.416667   3460078.083333  1118079.833333
# 2009-12-31  17969772.500000  19475228.500000  11427555.750000  1254427.250000
# 2010-12-31  18509167.500000  18633308.666667  17123103.916667  1825766.083333
# 2011-12-31  18327304.583333  17374860.833333  15179508.083333  2189076.833333
# 2012-12-31  17176172.583333  15989473.416667  10324190.916667  1941398.916667
# ...

# %%
pcmau.resample('AS-JAN')
# Out:
# 분 류           naver.com         daum.net         nate.com      google.com  \
# 2002-01-01   2167366.000000  18346874.500000   1734948.250000             NaN
# 2003-01-01   3841444.416667  20000133.666667   5155450.166667             NaN
# 2004-01-01   7287265.000000  21976173.916667   5826960.250000             NaN
# 2005-01-01  11250731.916667  22434847.000000   5177999.333333   400160.181818
# 2006-01-01  13509387.416667  21852508.583333   4504501.250000   590736.750000
# 2007-01-01  16132152.250000  21134526.666667   4728596.833333   865185.416667
# 2008-01-01  18020378.083333  20839384.416667   3460078.083333  1118079.833333
# 2009-01-01  17969772.500000  19475228.500000  11427555.750000  1254427.250000
# 2010-01-01  18509167.500000  18633308.666667  17123103.916667  1825766.083333
# 2011-01-01  18327304.583333  17374860.833333  15179508.083333  2189076.833333
# 2012-01-01  17176172.583333  15989473.416667  10324190.916667  1941398.916667
# ...

# %%
pcmau.resample('A', kind='period')
# Out:
# 분 류        naver.com         daum.net         nate.com      google.com  \
# 2002      2167366.000000  18346874.500000   1734948.250000             NaN
# 2003      3841444.416667  20000133.666667   5155450.166667             NaN
# 2004      7287265.000000  21976173.916667   5826960.250000             NaN
# 2005     11250731.916667  22434847.000000   5177999.333333   400160.181818
# 2006     13509387.416667  21852508.583333   4504501.250000   590736.750000
# 2007     16132152.250000  21134526.666667   4728596.833333   865185.416667
# 2008     18020378.083333  20839384.416667   3460078.083333  1118079.833333
# 2009     17969772.500000  19475228.500000  11427555.750000  1254427.250000
# 2010     18509167.500000  18633308.666667  17123103.916667  1825766.083333
# 2011     18327304.583333  17374860.833333  15179508.083333  2189076.833333
# 2012     17176172.583333  15989473.416667  10324190.916667  1941398.916667
# 2013     17319862.250000  14843589.583333   7436067.666667  1640313.166667
# ...

# %%
pcmau.resample('A', kind='period', how='sum') # mean, min, max, median, first, last, ohlc
# Out:
# 분 류  naver.com   daum.net   nate.com  google.com  communication-mail
# 2002       8669464   73387498    6939793         NaN            83149058
# 2003      46097333  240001604   61865402         NaN           266647811
# 2004      87447180  263714087   69923523         NaN           299312304
# 2005     135008783  269218164   62135992     4401762           318910379
# 2006     162112649  262230103   54054015     7088841           320837070
# 2007     193585827  253614320   56743162    10382225           333168708
# 2008     216244537  250072613   41520937    13416958           345975771
# 2009     215637270  233702742  137130669    15053127           343424541
# 2010     222110010  223599704  205477247    21909193           344654720
# 2011     219927655  208498330  182154097    26268922           336340004
# 2012     206114071  191873681  123890291    23296787           318081607
# 2013     207838347  178123075   89232812    19683758           306267301
# ...

# %%
pcmau.resample('Q', how='sum')
# Out:
# 분 류     naver.com  daum.net  nate.com  google.com  communication-mail
# 2002-09-30    1939599  18169858    556665         NaN            20712421
# 2002-12-31    6729865  55217640   6383128         NaN            62436637
# 2003-03-31    8553124  58283262  15582811         NaN            64758690
# 2003-06-30   10575421  58916724  13994155         NaN            66642339
# 2003-09-30   12675845  61216915  15675672         NaN            67617902
# 2003-12-31   14292943  61584703  16612764         NaN            67628880
# 2004-03-31   17732110  64266883  16150865         NaN            71605686
# 2004-06-30   20071725  65414850  18883598         NaN            73936103
# 2004-09-30   23351524  66276860  17378693         NaN            75789122
# 2004-12-31   26291821  67755494  17510367         NaN            77981393
# 2005-03-31   29712756  68203552  16134154      530180            79023153
# 2005-06-30   33316590  65933021  16030294     1074325            79191207
# ...

# %%
pcmau.resample('A', kind='period', how='ohlc')
# Out:
#      naver.com                                daum.net                      \
#           open      high       low     close      open      high       low
# 2002   1939599   2477848   1927483   2477848  18169858  19103068  17430340
# 2003   2576350   5302335   2576350   5302335  19090580  20910876  19090580
# 2004   5679813   9210256   5679813   9210256  20984888  22940698  20984888
# 2005   9770828  13126614   9496927  13126614  23228296  23228296  20772997
# 2006  13168048  14579239  12913092  14579239  22516226  22516226  21197499
# 2007  14989873  17541142  14726086  17541142  21206975  21510691  20720661
# 2008  17577149  18477813  17186642  18477813  21359218  21359218  20169548
# 2009  18431479  18856264  17340970  18856264  20516614  20516614  18821106
# 2010  18292916  19242916  18116824  19242916  19229655  19229655  17683084
# 2011  18876760  18876760  17769785  17995959  18161381  18207655  16754108
# ...
